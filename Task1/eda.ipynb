# %% [markdown]
# ## Task 1: Perform in depth EDA (Exploratory Data Analysis) on the given dataset.

# %%
# import necassary libraries
import pandas as pd
import matplotlib.pyplot as plt
# for axis range formatting
import matplotlib.ticker as ticker
import seaborn as sns

# %%
# read the dataset
df_copy = pd.read_csv('Walmart_customer_purchases.csv')
df = df_copy.copy()

# %%
# take a look at the first few rows of the dataset
df.head()
# Out:
#                             Customer_ID  Age  Gender           City  \
# 0  84607c1f-910c-44d5-b89f-e1ee06dd34c0   49  Female    New Cynthia
# 1  f2a81712-a73e-4424-8b39-4c615a0bd4ea   36   Other       Cruzport
# 2  da9be287-8b0e-4688-bccd-1a2cdd7567c6   52    Male    Jeffreytown
# 3  50ec6932-3ac7-492f-9e55-4b148212f302   47  Female  Jenniferburgh
# 4  8fdc3098-fc75-4b0f-983c-d8d8168c6362   43   Other      Kingshire
#
#       Category Product_Name Purchase_Date  Purchase_Amount    Payment_Method  \
# 0  Electronics   Smartphone    2024-08-30           253.26  Cash on Delivery
# 1     Clothing      T-Shirt    2024-12-21            73.19        Debit Card
# 2       Beauty      Perfume    2024-12-26           125.62       Credit Card
# 3  Electronics   Smartwatch    2024-11-04           450.32       Credit Card
# 4  Electronics   Smartphone    2024-10-07           369.28       Credit Card
#
#   Discount_Applied  Rating Repeat_Customer
# 0               No       1             Yes
# ...

# %%
df.dtypes
# Out:
# Customer_ID          object
# Age                   int64
# Gender               object
# City                 object
# Category             object
# Product_Name         object
# Purchase_Date        object
# Purchase_Amount     float64
# Payment_Method       object
# Discount_Applied     object
# Rating                int64
# Repeat_Customer      object
# dtype: object

# %%
df.shape
# Out:
# (50000, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Customer_ID       50000 non-null  object
#  1   Age               50000 non-null  int64
#  2   Gender            50000 non-null  object
#  3   City              50000 non-null  object
#  4   Category          50000 non-null  object
#  5   Product_Name      50000 non-null  object
#  6   Purchase_Date     50000 non-null  object
#  7   Purchase_Amount   50000 non-null  float64
#  8   Payment_Method    50000 non-null  object
#  9   Discount_Applied  50000 non-null  object
#  10  Rating            50000 non-null  int64
#  11  Repeat_Customer   50000 non-null  object
# dtypes: float64(1), int64(2), object(9)
# memory usage: 4.6+ MB

# %%
df.describe()
# Out:
#                 Age  Purchase_Amount        Rating
# count  50000.000000     50000.000000  50000.000000
# mean      38.945220       255.532230      2.998680
# std       12.398137       141.574416      1.417956
# min       18.000000        10.010000      1.000000
# 25%       28.000000       133.050000      2.000000
# 50%       39.000000       255.045000      3.000000
# 75%       50.000000       378.912500      4.000000
# max       60.000000       499.990000      5.000000

# %%
df.columns
# Out:
# Index(['Customer_ID', 'Age', 'Gender', 'City', 'Category', 'Product_Name',
#        'Purchase_Date', 'Purchase_Amount', 'Payment_Method',
#        'Discount_Applied', 'Rating', 'Repeat_Customer'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Customer_ID         0
# Age                 0
# Gender              0
# City                0
# Category            0
# Product_Name        0
# Purchase_Date       0
# Purchase_Amount     0
# Payment_Method      0
# Discount_Applied    0
# Rating              0
# Repeat_Customer     0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.nunique()
# Out:
# Customer_ID         50000
# Age                    43
# Gender                  3
# City                25096
# Category                4
# Product_Name           16
# Purchase_Date         366
# Purchase_Amount     31378
# Payment_Method          4
# Discount_Applied        2
# Rating                  5
# Repeat_Customer         2
# dtype: int64

# %% [markdown]
# Age Column

# %%
df['Age'].value_counts()
# Out:
# Age
# 45    1227
# 54    1221
# 28    1213
# 22    1210
# 24    1209
# 52    1208
# 34    1201
# 42    1197
# 23    1197
# 44    1193
# 35    1187
# 37    1184
# 27    1183
# 51    1182
# 38    1178
# 19    1176
# 39    1169
# 48    1168
# 25    1166
# 59    1165
# 31    1165
# 18    1162
# 26    1160
# 32    1158
# 30    1155
# 43    1152
# 60    1151
# 40    1151
# 57    1148
# 58    1147
# 49    1144
# 50    1141
# 36    1139
# 47    1139
# 21    1138
# 46    1133
# 56    1131
# 20    1125
# 41    1117
# 33    1110
# 53    1105
# 55    1104
# 29    1091
# Name: count, dtype: int64

# %%
sns.boxplot(x=df['Age'])
# Out:
# <Axes: xlabel='Age'>

# %%
df['Age'].max()
# Out:
# np.int64(60)

# %%
df['Age'].min()
# Out:
# np.int64(18)

# %%
df['Age'].median()
# Out:
# np.float64(39.0)

# %%
df['Age'].mean()
# Out:
# np.float64(38.94522)

# %% [markdown]
# ### Age column — Findings
#
# - Minimum age: 18
# - Median age: 39
# - Mean age: 38.9
# - Maximum age: 60

# %% [markdown]
# Gender Column:

# %%
df['Gender'].value_counts(normalize=True)*100
# Out:
# Gender
# Other     33.502
# Male      33.288
# Female    33.210
# Name: proportion, dtype: float64

# %%
df['City'].value_counts().head(5)
# Out:
# City
# New Michael      44
# North Michael    42
# Lake Michael     41
# East Michael     36
# Port Michael     34
# Name: count, dtype: int64

# %%
df['City'].value_counts().tail(5)
# Out:
# City
# New Cesar         1
# West Larrystad    1
# Mcleanton         1
# West Lorishire    1
# Shermantown       1
# Name: count, dtype: int64

# %% [markdown]
# Category Column:

# %%
df['Category'].value_counts()
# Out:
# Category
# Electronics    12642
# Home           12492
# Beauty         12447
# Clothing       12419
# Name: count, dtype: int64

# %%
df['Product_Name'].value_counts().head(4)
# Out:
# Product_Name
# Headphones    3261
# T-Shirt       3206
# Smartwatch    3177
# Face Cream    3174
# Name: count, dtype: int64

# %%
sns.boxplot(x=df['Purchase_Amount'])
# Out:
# <Axes: xlabel='Purchase_Amount'>

# %%
df['Purchase_Amount'].max()
# Out:
# np.float64(499.99)

# %%
df['Payment_Method'].value_counts()
# Out:
# Payment_Method
# Debit Card          12589
# Credit Card         12528
# Cash on Delivery    12496
# UPI                 12387
# Name: count, dtype: int64

# %%
df['Discount_Applied'].value_counts()
# Out:
# Discount_Applied
# No     25018
# Yes    24982
# Name: count, dtype: int64

# %%
df['Rating'].value_counts()
# Out:
# Rating
# 1    10099
# 4    10045
# 5    10029
# 2     9971
# 3     9856
# Name: count, dtype: int64

# %%
df['Repeat_Customer'].value_counts()
# Out:
# Repeat_Customer
# Yes    25244
# No     24756
# Name: count, dtype: int64

# %%
sns.boxplot(data=df, x='Gender', y='Purchase_Amount')
# Out:
# <Axes: xlabel='Gender', ylabel='Purchase_Amount'>

# %%
# sns.barplot(data=df,x='City',y='Purchase_Amount')

# %%
# top 5 cities with purchase amount
df.groupby('City')['Purchase_Amount'].agg(['sum','mean','count']).nlargest(5,'sum')
# Out:
#                     sum        mean  count
# City
# North Michael  11478.75  273.303571     42
# East Michael   10866.51  301.847500     36
# New Michael    10574.68  240.333636     44
# Lake Michael   10500.51  256.110000     41
# West Michael    9361.14  283.670909     33

# %%
# top 5 cities by purchases
top_5_cities_purchases = df.groupby('City')['Purchase_Amount'].sum().sort_values(ascending=False).head(5)

# %%
sns.barplot(
    x=top_5_cities_purchases.index,
    y=top_5_cities_purchases.values,
    order=top_5_cities_purchases.index,
    hue=top_5_cities_purchases.index,
    palette='viridis')
plt.title("Top 5 cities by Purchase Amount")
plt.show()

# %%
sns.countplot(data=df, x='Category', hue='Gender')
# Out:
# <Axes: xlabel='Category', ylabel='count'>

# %%
df.groupby(['Category','Gender'])['Purchase_Amount'].sum()
# Out:
# Category     Gender
# Beauty       Female    1076998.27
#              Male      1060536.94
#              Other     1037192.69
# Clothing     Female    1058347.36
#              Male      1020506.54
#              Other     1067124.08
# Electronics  Female    1049579.57
#              Male      1098067.09
#              Other     1113041.43
# Home         Female    1072303.88
#              Male      1052307.49
#              Other     1070606.14
# Name: Purchase_Amount, dtype: float64

# %%
gender_cat_purchases = df.groupby(['Category','Gender'])['Purchase_Amount'].sum().reset_index()

# %%
sns.barplot(
    data=df,
    x='Category',
    y='Purchase_Amount',
    hue ='Gender'
)
# Out:
# <Axes: xlabel='Category', ylabel='Purchase_Amount'>

# %%
df.groupby('Payment_Method')['Purchase_Amount'].sum()
# Out:
# Payment_Method
# Cash on Delivery    3195777.32
# Credit Card         3197688.67
# Debit Card          3209382.11
# UPI                 3173763.38
# Name: Purchase_Amount, dtype: float64

# %%
df.groupby('Payment_Method')['Purchase_Amount'].sum()
# Out:
# Payment_Method
# Cash on Delivery    3195777.32
# Credit Card         3197688.67
# Debit Card          3209382.11
# UPI                 3173763.38
# Name: Purchase_Amount, dtype: float64

# %%
df.columns
# Out:
# Index(['Customer_ID', 'Age', 'Gender', 'City', 'Category', 'Product_Name',
#        'Purchase_Date', 'Purchase_Amount', 'Payment_Method',
#        'Discount_Applied', 'Rating', 'Repeat_Customer'],
#       dtype='object')

# %%
sns.countplot(data=df,x='Payment_Method')
# Out:
# <Axes: xlabel='Payment_Method', ylabel='count'>

# %%
sns.countplot(data=df, x='Repeat_Customer')
# Out:
# <Axes: xlabel='Repeat_Customer', ylabel='count'>

# %%
sns.histplot(df['Age'], kde=True)
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
sns.boxplot(data=df, x='Rating')
# Out:
# <Axes: xlabel='Rating'>

# %%
sns.histplot(df['Rating'])
# Out:
# <Axes: xlabel='Rating', ylabel='Count'>

# %%
sns.scatterplot(data=df, x='Discount_Applied',
y='Purchase_Amount')
# Out:
# <Axes: xlabel='Discount_Applied', ylabel='Purchase_Amount'>

# %%
sns.barplot(x='Gender',y='Purchase_Amount',data=df)
# Out:
# <Axes: xlabel='Gender', ylabel='Purchase_Amount'>

# %%
sns.countplot(x='Category',hue='Gender',data=df)
# Out:
# <Axes: xlabel='Category', ylabel='count'>

# %%
sns.boxplot(x='Gender',y='Rating', hue='Discount_Applied',data=df)
# Out:
# <Axes: xlabel='Gender', ylabel='Rating'>

# %%
df.corr
# Out:
# <bound method DataFrame.corr of                                 Customer_ID  Age  Gender           City  \
# 0      84607c1f-910c-44d5-b89f-e1ee06dd34c0   49  Female    New Cynthia
# 1      f2a81712-a73e-4424-8b39-4c615a0bd4ea   36   Other       Cruzport
# 2      da9be287-8b0e-4688-bccd-1a2cdd7567c6   52    Male    Jeffreytown
# 3      50ec6932-3ac7-492f-9e55-4b148212f302   47  Female  Jenniferburgh
# 4      8fdc3098-fc75-4b0f-983c-d8d8168c6362   43   Other      Kingshire
# ...                                     ...  ...     ...            ...
# 49995  80853da9-ef96-4c83-9191-bc872c3968a9   48    Male   Barbaramouth
# 49996  97df1ed3-4041-474c-8ce8-958c816fc30a   51  Female      Troyshire
# 49997  948efe87-82a3-4a38-9dd6-30d44ad6f879   51    Male   South Rachel
# 49998  9804d52f-35cd-4af3-a9e3-cbb8367396f0   33   Other  Courtneyville
# 49999  a7f2b17c-f5c8-46a5-9322-319c4a2772ca   18   Other     Norrisland
#
#           Category Product_Name Purchase_Date  Purchase_Amount  \
# ...

# %%
sns.heatmap(df.corr(numeric_only=True),annot=True,cmap='coolwarm')
# Out:
# <Axes: >

# %%
sns.countplot(x='Gender', data=df)
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
sns.histplot(df['Purchase_Amount'], bins=20, kde=True)
# Out:
# <Axes: xlabel='Purchase_Amount', ylabel='Count'>

# %%
sns.boxplot(x='Gender', y='Purchase_Amount', data=df)
# Out:
# <Axes: xlabel='Gender', ylabel='Purchase_Amount'>

# %%
sns.countplot(x='Category', hue='Gender', data=df)
# Out:
# <Axes: xlabel='Category', ylabel='count'>

# %%
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap='coolwarm')
# Out:
# <Axes: >

# %%
df.columns
# Out:
# Index(['Customer_ID', 'Age', 'Gender', 'City', 'Category', 'Product_Name',
#        'Purchase_Date', 'Purchase_Amount', 'Payment_Method',
#        'Discount_Applied', 'Rating', 'Repeat_Customer'],
#       dtype='object')

# %%
df['Purchase_Date'] = pd.to_datetime(df['Purchase_Date'])

# %%
df['Month'] = df['Purchase_Date'].dt.month_name()
df['Year'] = df['Purchase_Date'].dt.year

# %%
df.columns
# Out:
# Index(['Customer_ID', 'Age', 'Gender', 'City', 'Category', 'Product_Name',
#        'Purchase_Date', 'Purchase_Amount', 'Payment_Method',
#        'Discount_Applied', 'Rating', 'Repeat_Customer', 'Month', 'Year'],
#       dtype='object')

# %%
ax = sns.histplot(x='Year',bins=2,data=df,discrete=True)
ax.set_xticks([2024,2025])
plt.show()

# %%
df['Purchase_Amount'].median()
# Out:
# np.float64(255.04500000000002)

# %%
df['Discount_Applied']
# Out:
# 0         No
# 1        Yes
# 2        Yes
# 3         No
# 4        Yes
#         ...
# 49995     No
# 49996    Yes
# 49997    Yes
# 49998     No
# 49999     No
# Name: Discount_Applied, Length: 50000, dtype: object

# %%
df.dtypes
# Out:
# Customer_ID                 object
# Age                          int64
# Gender                      object
# City                        object
# Category                    object
# Product_Name                object
# Purchase_Date       datetime64[ns]
# Purchase_Amount            float64
# Payment_Method              object
# Discount_Applied            object
# Rating                       int64
# Repeat_Customer             object
# Month                       object
# Year                         int32
# dtype: object

# %%
year_2024 = df.query("Year == 2024")

# %%
sns.lineplot(x='Month', y='Purchase_Amount',data=year_2024,marker='o')
plt.title("Purchase Amount by Month in 2024")
plt.xticks(rotation=45)
plt.show()

# %%
total_sales = df['Purchase_Amount'].sum()
print(total_sales)
# Out:
# 12776611.48

# %%
year_2024['Purchase_Amount'].sum()
# Out:
# np.float64(11403438.49)

# %%
monthly_sales = df.groupby('Month')['Purchase_Amount'].sum().reset_index()
monthly_sales = pd.DataFrame(monthly_sales)
monthly_sales.columns = ['Month','Sales']

# %%
monthly_sales.max()
# Out:
# Month     September
# Sales    1096915.31
# dtype: object

# %%
1096915
# Out:
# 1096915

# %%
monthly_sales
# Out:
#         Month       Sales
# 0       April  1044547.67
# 1      August  1078813.36
# 2    December  1074544.83
# 3    February   998954.51
# 4     January  1066162.87
# 5        July  1081042.04
# 6        June  1047367.77
# 7       March  1096915.31
# 8         May  1078867.98
# 9    November  1072828.45
# 10    October  1081708.11
# 11  September  1054858.58

# %%
ax = sns.lineplot(
    data=monthly_sales,
    x='Month',
    y='Sales',
    marker='o',
    color='red'
)
plt.title("Total Sales by Month")
ax.yaxis.set_major_formatter(ticker.EngFormatter(unit=''))
plt.xticks(rotation=45)
plt.show()

# %%
# Total Sales By Category
sales_category = df.groupby('Category')['Purchase_Amount'].sum()

# %%
sales_category
# Out:
# Category
# Beauty         3174727.90
# Clothing       3145977.98
# Electronics    3260688.09
# Home           3195217.51
# Name: Purchase_Amount, dtype: float64

# %%
ax = sns.barplot(x=sales_category.index,y=sales_category.values)
ax.yaxis.set_major_formatter(ticker.EngFormatter())

# %%
# top 10 product names
top_products = df.groupby('Product_Name')['Purchase_Amount'].sum().reset_index()

top_products = pd.DataFrame(top_products)
top_products.columns = ['Product','Sales']

# %%
ax = sns.lineplot(
    data=top_products,
    x='Product',
    y='Sales'
)
ax.yaxis.set_major_formatter(ticker.EngFormatter())
plt.title("Products vs Total Sales")
plt.xticks(rotation=90)
plt.show()

# %%
# Total Sales By Gender and discount applied with
# payment method

# %%
cross = pd.crosstab(df['Gender'], df['Category'])
sns.heatmap(cross, annot=True, cmap='viridis',fmt='.0f')
plt.title("Purchases by Gender and Category")
plt.show()
